# %% [markdown]
# <a href="https://colab.research.google.com/github/Ariascarljans/58010-DSAA/blob/main/Longquiz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# G28 = (Vg28,Eg28)
#
#
#
# VG28 = (E, F, H, I, J, K, M, P)
#
# EG28 = ( (H, I), (H, J), (H, K), (I,H), (I,E), (J,H), (J,E) ,(E,J) (E,I), (E,K) (K,H) , (K,E), (K,F), (F,J)
#
#  (F,I), (M,E) (P,F)

# %%
          class graph:
   def __init__(self,gdict=None):
      if gdict is None:
         gdict = []
      self.gdict = gdict

   def getVertices(self):
      return list(self.gdict.keys())

graph_elements = {
   "E" : ["I","J", "K", "M"],
   "F" : ["J", "I", "K", "P"],
   "J" : ["H", "E", "F"],
   "H" : ["J", "K", "I"],
   "I" : ["H", "F", "E"],
   "K" : ["H", "E", "F"],
   "M" : ["E"],
   "P" : ["F"]
}
g = graph(graph_elements)
print(g.getVertices())

# %%
class graph:
   def __init__(self,gdict=None):
      if gdict is None:
         gdict = {}
      self.gdict = gdict

   def edges(self):
      return self.findedges()

   def findedges(self):
      edgename = []
      for vrtx in self.gdict:
         for nxtvrtx in self.gdict[vrtx]:
            if {nxtvrtx, vrtx} not in edgename:
               edgename.append({vrtx, nxtvrtx})
      return edgename

graph_elements = {
    "E" : ["I","J", "K", "M"],
   "F" : ["J", "I", "K", "P"],
   "J" : ["H", "E", "F"],
   "H" : ["J", "K", "I"],
   "I" : ["H", "F", "E"],
   "K" : ["H", "E", "F"],
   "M" : ["E"],
   "P" : ["F"]
}
g = graph(graph_elements)
print(g.edges())

# %% [markdown]
# ![Screenshot 2023-10-25 085929.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-10-25 090234.png](data:image/png;base64,...)
